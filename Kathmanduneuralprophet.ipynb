# %%
import pandas as pd

# %%
# !pip install git+https://github.com/ourownstory/neural_prophet.git numpy==1.23.5

# %%
import numpy as np

# %%
df = pd.read_csv("/content/Datasets-kathmandu.csv")

# %%
import matplotlib

# %%
plt = df.plot(x= "Date", y = "Peak Load")

# %%
pip install neuralprophet
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.1/137.1 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 13.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.2/378.2 kB 16.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.5/829.5 kB 18.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 41.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 97.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 89.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 18.1 MB/s eta 0:00:00
# ...

# %%
from neuralprophet import NeuralProphet, set_log_level

# %%
df.rename(columns={"Date": "ds", "Peak Load": "y"}, inplace=True)

# %%
columns_to_delete = ["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"]  # Replace with your column names
df.drop(columns=columns_to_delete, inplace=True)

# %%
df.head()

# %%
df.shape

# %%
set_log_level("ERROR")

# %%
m = NeuralProphet()

# %%
m.set_plotting_backend("plotly")

# %%
nan_rows = df[df['ds'].isnull()]
print(nan_rows)

# %%
df = df.dropna(subset=['ds'])

# %%
df['ds'] = pd.to_datetime(df['ds'], errors='coerce')

# Drop rows with invalid dates
df = df.dropna(subset=['ds'])

# %%
metrics = m.fit(df)
